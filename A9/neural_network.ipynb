# %% [markdown]
# # Mustererkennung/Machine Learning - Assignment 9

# %% [markdown]
# ### Load the spam dataset:

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

# %%
path_to_train = 'zip.train'
path_to_test = 'zip.test'
training_data = np.array(pd.read_csv(path_to_train, sep=' ', header=None))
test_data = np.array(pd.read_csv(path_to_test, sep =' ',header=None))

X_train, y_train = training_data[:,1:-1], training_data[:,0]
X_test, y_test = test_data[:,1:], test_data[:,0]

# %% [markdown]
# ## 1. Add Backpropagation to your MLP and train the model on the ZIP-Dataset

# %%
def standardize(x, means, stds):
    return (x - means) / stds

def to_one_hot(y, num_classes):
    return np.eye(num_classes)[y.astype(np.uint)]

def softmax(x):
    exp = np.exp(x)
    summed = np.sum(exp, axis=1, keepdims=True)
    return exp / summed

def accuracy(y_true, y_pred):
    y_true = np.argmax(y_true, axis=1)
    y_pred = np.argmax(y_pred, axis=1)
    return np.mean(y_true == y_pred)

class Sigmoid():
    def forward(self, x):
        z = 1 / (1 + np.exp(-x)) 
        self.z = z
        return z
    
    def backward(self, right_dev):
        return self.z * (1.0 - self.z) * right_dev.T
    
class CategoricalCrossEntropy():
    """
    softmax + categorical crossentropy
    """
    def forward(self, x, y):
        y_pred = softmax(x)
        loss = (1.0 / x.shape[0]) * -np.sum(np.log(np.max(y_pred * y, axis=1)))
        self.y_pred = y_pred
        self.y_true = y
        return loss
        
    def backward(self, right_dev):
        return (self.y_pred - self.y_true) * right_dev
    
class DenseLayer():
    def __init__(self, input_dims, output_dims, activation=None):
        self.w = np.random.normal(size=(input_dims, output_dims))
        self.b = np.ones((1, output_dims))
        self.activation = activation
        
    def forward(self, x):
        self.x = x
        x = x @ self.w + self.b
        if self.activation:
            x = self.activation.forward(x)
        return x
    
    def backward(self, right_dev):
        if self.activation:
            act_grad = self.activation.backward(right_dev)
        else:
            act_grad = right_dev
        self.grad_w = self.x.T @ act_grad
        self.grad_b = np.sum(act_grad, axis=0, keepdims=True)
        return self.w @ act_grad.T
    
    def apply_gradients(self, lr):
        self.w = self.w - lr * self.grad_w
        self.b = self.b - lr * self.grad_b
    
class NeuralNetwork():
    def __init__(self, layers, loss):
        self.layers = layers
        self.loss = loss
        
    def forward(self, x):
        for layer in self.layers:
            x = layer.forward(x)
        return x
    
    def predict(self, x):
        return softmax(self.forward(x))
    
    def fit(self, x, y, epochs, lr, x_val = None, y_val = None):
        losses = []
        train_accs = []
        val_accs = []
        
        for epoch in range(1, epochs + 1):
            y_pred = self.forward(x)
            loss = self.loss.forward(y_pred, y)
            right_dev = 1.0
            right_dev = self.loss.backward(right_dev)
            for layer in self.layers[::-1]:
                right_dev = layer.backward(right_dev)
            for layer in self.layers:
                layer.apply_gradients(lr)
            
            if isinstance(x_val, np.ndarray) and isinstance(y_val, np.ndarray):
                y_pred_val = self.predict(x_val)
                val_accs.append(accuracy(y_val, y_pred_val))
            
            train_accs.append(accuracy(y, softmax(y_pred)))
            losses.append(loss)
                   
        return losses, train_accs, val_accs

# %%
num_classes = len(np.unique(y_train))
y_train, y_test = to_one_hot(y_train, num_classes), to_one_hot(y_test, num_classes)
train_means, train_stds = np.mean(X_train, axis=0), np.std(X_train, axis=0)
X_train, X_test = standardize(X_train, train_means, train_stds), standardize(X_test, train_means, train_stds)

# %%
best_acc = 0.0

for width in range(10, 50, 10):
    for depth in range(0, 4):
        first_layer = DenseLayer(X_train.shape[1], width, activation=Sigmoid())
        layers = [first_layer]
        for i in range(1, depth - 1):
            layers.append(DenseLayer(width, width, activation=Sigmoid()))
        layers.append(DenseLayer(width, num_classes))
        clf = NeuralNetwork(layers, CategoricalCrossEntropy())
        losses, train_accs, val_accs = clf.fit(X_train, y_train, epochs=500, lr=0.00005, x_val=X_test, y_val=y_test)
        print(f"For a depth of {depth + 2} and a width of {width} the network has an accuracy of {round(val_accs[-1], 4)}")
        if val_accs[-1] > best_acc:
            best_acc = val_accs[-1]
            best_settings = {
                "width": width,
                "depth": depth + 2,
                "losses": losses,
                "train_accs": train_accs,
                "val_accs": val_accs,
                "clf": clf
            }
# Out:
# For a depth of 2 and a width of 10 the network has an accuracy of 0.7564
# For a depth of 3 and a width of 10 the network has an accuracy of 0.7554
# For a depth of 4 and a width of 10 the network has an accuracy of 0.7653
# For a depth of 5 and a width of 10 the network has an accuracy of 0.6911
# For a depth of 2 and a width of 20 the network has an accuracy of 0.7962
# For a depth of 3 and a width of 20 the network has an accuracy of 0.7788
# For a depth of 4 and a width of 20 the network has an accuracy of 0.7942
# For a depth of 5 and a width of 20 the network has an accuracy of 0.7663
# For a depth of 2 and a width of 30 the network has an accuracy of 0.7992
# For a depth of 3 and a width of 30 the network has an accuracy of 0.8092
# For a depth of 4 and a width of 30 the network has an accuracy of 0.8087
# For a depth of 5 and a width of 30 the network has an accuracy of 0.7698
# For a depth of 2 and a width of 40 the network has an accuracy of 0.8291
# For a depth of 3 and a width of 40 the network has an accuracy of 0.7977
# For a depth of 4 and a width of 40 the network has an accuracy of 0.8261
# For a depth of 5 and a width of 40 the network has an accuracy of 0.8017

# %%
print(f"The best architecture we found is {best_settings['depth']} layers with {best_settings['width']} neurons, which has an accuracy of {round(best_settings['val_accs'][-1], 4)}.")
# Out:
# The best architecture we found is 2 layers with 40 neurons, which has an accuracy of 0.8291.

# %%
plt.plot(list(range(len(best_settings["losses"]))), best_settings["losses"])
plt.xlabel("epoch")
plt.ylabel("training loss")
plt.show()

# %%
plt.plot(list(range(len(best_settings["train_accs"]))), best_settings["train_accs"], label="training set")
plt.plot(list(range(len(best_settings["val_accs"]))), best_settings["val_accs"], label="validation set")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend()
plt.show()

# %% [markdown]
# b) Show some digits that are classified incorrectly

# %%
y_pred = best_settings["clf"].predict(X_test)

y_pred = np.argmax(y_pred, axis=1)
y_test = np.argmax(y_test, axis=1)
X_missclassified = X_test[y_pred != y_test]

# %%
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
    img = np.reshape(X_missclassified[i - 1], (16, 16))
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %% [markdown]
# c) Plot your first weight layer as a grayscale image.

# %%
plt.imshow(best_settings["clf"].layers[0].w, cmap='gray')
plt.show()
